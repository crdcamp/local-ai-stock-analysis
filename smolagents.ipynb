# %% [markdown]
# # Local AI Stock Search

# %%
from smolagents import WebSearchTool

search_tool = WebSearchTool()
ticker = "NET"
ticker_name = "Cloudflare"

print(search_tool(f"Search for finance news involving the ticker {ticker}. The name of the company is {ticker_name}"))
# Out:
# ## Search Results
#
# [Syndax Pharmaceuticals, Inc. (SNDX) - Yahoo Finance](https://finance.yahoo.com/quote/SNDX/news/)
# Get the latest Syndax Pharmaceuticals, Inc. ( SNDX ) stock news and headlines to help you in your trading and investing decisions.
#
# [Syndax Pharmaceuticals (SNDX) Stock Price, News & Analysis - MarketBeat](https://www.marketbeat.com/stocks/NASDAQ/SNDX/)
# This is a higher news sentiment than the 0.79 average news sentiment score of Medical companies. News Coverage This Week MarketBeat has tracked 16 news articles for Syndax Pharmaceuticals this week, compared to 6 articles on an average week. Search Interest Only 2 people have searched for SNDX on MarketBeat in the last 30 days.
#
# [Syndax Pharmaceuticals (SNDX) News Today - MarketBeat](https://www.marketbeat.com/stocks/NASDAQ/SNDX/news/)
# ...

# %% [markdown]
# # Scraping Sentiment Data

# %%
from smolagents import LiteLLMModel, CodeAgent, DuckDuckGoSearchTool

model = LiteLLMModel(
    model_id="ollama_chat/deepseek-r1:14b",
    api_key="ollama"
)

authorized_imports = ["cssselect", "requests", "selenium", "selenium.webdriver", "selenium.webdriver.common.by", "bs4"]
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model, additional_authorized_imports=authorized_imports)

site = "https://finance.yahoo.com/"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Cache-Control': 'max-age=0',
    'Referer': 'https://www.google.com/'
}

agent.run(f"""
          Webscrape this website: {site}.

          Use the headers defined here when webscraping: {headers}.

          Extract all headlines from the site.
          """)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Webscrape this website: https://finance.yahoo.com/.                                                             │
# │                                                                                                                 │
# │           Use the headers defined here when webscraping: {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64;   │
# │ x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36', 'Accept':                          │
# │ 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',             │
# │ 'Accept-Language': 'en-US,en;q=0.9', 'Accept-Encoding': 'gzip, deflate, br', 'Connection': 'keep-alive',        │
# ...
